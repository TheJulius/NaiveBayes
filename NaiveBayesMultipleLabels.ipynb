# %%
#Importar biblioteca de conjunto de dados scikit-learn
from sklearn import datasets

#Importar biblioteca pyplot
import matplotlib.pyplot as plt

# Importar a função train_test_split
from sklearn.model_selection import train_test_split

#Importar modelo Gaussiano Naive Bayes
from sklearn.naive_bayes import GaussianNB

#Importar módulo de métricas scikit-learn para cálculo de precisão
from sklearn import metrics

#Importar função RocCurveDisplay
from sklearn.metrics import RocCurveDisplay

#Importar biblioteca SVC
from sklearn.svm import SVC

#Importar dataset para plotar grafico
from sklearn.datasets import load_wine

#Importar biblioteca seaborn
import seaborn as sns

#Importar biblioteca pandas
import pandas as pd

# %%
#Carregar dataset
wine = datasets.load_wine()

# %%
#Imprimir as 13 caracteristicas
print ("Caracteristicas: ", wine.feature_names)

#Imprima o tipo de rótulo do vinho (class_0, class_1, class_2)
print ("Rótulos: ", wine.target_names)
# Out:
# Caracteristicas:  ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Rótulos:  ['class_0' 'class_1' 'class_2']

# %%
#Imprimir data(feature)shape
wine.data.shape
# Out:
# (178, 13)

# %%
df = pd.DataFrame(wine.data, columns=wine.feature_names)
sns.set(rc={'figure.figsize':(15,10)})
sns.heatmap(df.iloc[:,:-1].corr(), annot=True, cmap="YlGnBu")
plt.show()

# %%
plt.scatter(wine['data'][:, 0], wine['data'][:, 9], c=wine['target'])
plt.title('Dataset reconhecimento de vinhos')
plt.xlabel(wine['feature_names'][0])
plt.ylabel(wine['feature_names'][9])
plt.show()

# %%
# Extrair as informações
data = pd.DataFrame(wine['data'], columns=wine['feature_names'])
# Extrair a coluna alvo
target = pd.DataFrame(wine['target'], columns=['cultivator'])
# Combinar no dataset
df = pd.concat([target, data], axis='columns')

# Plot
plt.scatter(df['hue'], df['malic_acid'], c=df['cultivator'])
plt.title('Dataset reconhecimento de vinhos')
plt.xlabel('hue')
plt.ylabel('malic_acid')
plt.show()

# %%
#Dividir o conjunto de dados em conjunto de treinamento e conjunto de teste
X_train, X_test, y_train, y_test = train_test_split(wine.data, wine.target, test_size=0.3,random_state=109) # 70% treinamento e 30% teste

# %%
#Criar um Classificador Gaussiano
gnb = GaussianNB()

#Treinar o modelo usando os conjuntos de treinamento
gnb.fit(X_train, y_train)

#Prever a resposta para o conjunto de dados de teste
y_pred = gnb.predict(X_test)

# %%
# Precisão do modelo, com que frequência o classificador está correto?
print("Precisão:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Precisão: 0.9074074074074074
